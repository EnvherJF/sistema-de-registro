# %% [markdown]
# <a href="https://colab.research.google.com/github/EnvherJF/sistema-de-registro/blob/main/Telecom_X.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Extraccion**

# %%
import pandas as pd

datos = pd.read_json('/content/TelecomX_Data.json')

# %%
datos.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# ## **Transformacion**

# %%
import numpy as np

datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
datos['Churn'] = datos['Churn'].str.lower()

# %%
datos.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    no  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    no  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
columnas = list(datos.columns)
columnas
# Out:
# ['customerID', 'Churn', 'customer', 'phone', 'internet', 'account']

# %%
print(datos.dtypes)
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %%
datos.explode('phone').head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    no  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 0  0002-ORFBO    no  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    no  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 1  0003-MKNFE    no  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#            phone                                           internet  \
# 0   PhoneService  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 0  MultipleLines  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1   PhoneService  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  MultipleLines  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2   PhoneService  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# ...

# %%
len(datos)
# Out:
# 7267

# %%
pd.set_option('display.max_colwidth', None)

# %%
datos.head()
# Out:
#    customerID Churn  \
# 0  0002-ORFBO    no
# 1  0003-MKNFE    no
# 2  0004-TLHLJ   yes
# 3  0011-IGKFF   yes
# 4  0013-EXCHZ   yes
#
#                                                                                        customer  \
# 0  {'gender': 'Female', 'SeniorCitizen': 0, 'Partner': 'Yes', 'Dependents': 'Yes', 'tenure': 9}
# 1      {'gender': 'Male', 'SeniorCitizen': 0, 'Partner': 'No', 'Dependents': 'No', 'tenure': 9}
# 2      {'gender': 'Male', 'SeniorCitizen': 0, 'Partner': 'No', 'Dependents': 'No', 'tenure': 4}
# 3    {'gender': 'Male', 'SeniorCitizen': 1, 'Partner': 'Yes', 'Dependents': 'No', 'tenure': 13}
# 4   {'gender': 'Female', 'SeniorCitizen': 1, 'Partner': 'Yes', 'Dependents': 'No', 'tenure': 3}
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...

# %%
# Identificar las columnas más relevantes para el análisis de evasión.
datos[['customerID', 'customer', 'account']].head()
# Out:
#    customerID  \
# 0  0002-ORFBO
# 1  0003-MKNFE
# 2  0004-TLHLJ
# 3  0011-IGKFF
# 4  0013-EXCHZ
#
#                                                                                        customer  \
# 0  {'gender': 'Female', 'SeniorCitizen': 0, 'Partner': 'Yes', 'Dependents': 'Yes', 'tenure': 9}
# 1      {'gender': 'Male', 'SeniorCitizen': 0, 'Partner': 'No', 'Dependents': 'No', 'tenure': 9}
# 2      {'gender': 'Male', 'SeniorCitizen': 0, 'Partner': 'No', 'Dependents': 'No', 'tenure': 4}
# 3    {'gender': 'Male', 'SeniorCitizen': 1, 'Partner': 'Yes', 'Dependents': 'No', 'tenure': 13}
# 4   {'gender': 'Female', 'SeniorCitizen': 1, 'Partner': 'Yes', 'Dependents': 'No', 'tenure': 3}
#
#                                                                                                                                             account
# 0              {'Contract': 'One year', 'PaperlessBilling': 'Yes', 'PaymentMethod': 'Mailed check', 'Charges': {'Monthly': 65.6, 'Total': '593.3'}}
# ...

# %%
# para ver elementos de una columna.
# pd.json_normalize(datos['internet'])

# %% [markdown]
# ## **Carga y Analisis**
